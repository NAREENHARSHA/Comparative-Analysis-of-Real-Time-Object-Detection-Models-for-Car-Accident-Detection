# %%
# !git clone https://github.com/ultralytics/yolov5.git  # Clone YOLOv5 repo
# %cd yolov5
# !pip install -r requirements.txt  # Install dependencies\
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="IuA6Ni5hy26TwBSGSMSX")  # Use your API key
project = rf.workspace("harsha-ovlak").project("accident-detection-model-1mcto")
version = project.version(1)
dataset = version.download("yolov5")  # Download in YOLOv5 format
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Accident-detection-model-1 in yolov5pytorch:: 100%|██████████| 6492/6492 [00:01<00:00, 5229.82it/s]

# %%
import os

# Define dataset path
dataset_path = "/content/yolov5/Accident-detection-model-1"

# Train YOLOv5 model
# !python train.py --img 640 --batch 16 --epochs 20 --data {dataset_path}/data.yaml --weights yolov5s.pt --device 0
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#        4/19      4.37G    0.04594   0.009626          0         11        640:  36% 57/157 [00:23<00:49,  2.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/19      4.37G    0.04589    0.00965          0         17        640:  37% 58/157 [00:24<00:50,  1.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/19      4.37G    0.04592   0.009646          0         17        640:  38% 59/157 [00:24<00:43,  2.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
print(os.path.exists(os.path.join(dataset_path, "data.yaml")))
# Out:
# True

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data /content/Accident-detection-model-1/data.yaml --img 640 --iou 0.5 --device 0
# Out:
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 603, in <module>
#     opt = parse_opt()
#           ^^^^^^^^^^^
#   File "/content/yolov5/val.py", line 541, in parse_opt
#     opt.data = check_yaml(opt.data)  # check YAML
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/general.py", line 478, in check_yaml
#     return check_file(file, suffix)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/general.py", line 506, in check_file
#     assert len(files), f"File not found: {file}"  # assert file was found
#            ^^^^^^^^^^
# AssertionError: File not found: /content/Accident-detection-model-1/data.yaml

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data /content/Accident-detection-model-1/data.yaml --img 640 --device 0 --save-txt --save-conf --save-json
# Out:
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 603, in <module>
#     opt = parse_opt()
#           ^^^^^^^^^^^
#   File "/content/yolov5/val.py", line 541, in parse_opt
#     opt.data = check_yaml(opt.data)  # check YAML
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/general.py", line 478, in check_yaml
#     return check_file(file, suffix)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/general.py", line 506, in check_file
#     assert len(files), f"File not found: {file}"  # assert file was found
#            ^^^^^^^^^^
# AssertionError: File not found: /content/Accident-detection-model-1/data.yaml

# %%
from utils.plots import plot_results
plot_results("/content/yolov5/runs/train/exp2/results.csv")  # Adjust path if needed

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source /content/yolov5/Accident-detection-model-1/test/images --img 640 --conf 0.25 --device 0
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/yolov5/Accident-detection-model-1/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-410-g1953d472 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 438, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 433, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
# ...
